# %%
#Scipy 
import skimage
skimage.__version__
# Out:
# '0.16.2'

# %%
#이미지작업
#scipy.misc에서는 imread 없음. => skimage.io.imread  
#scipy.misc에 imreszie 없음 => skimage.transform.resize
import skimage.io
import skimage.transform
img = skimage.io.imread('../images/cat.jpg')
print(img.dtype,img.shape)

img_tinted = img *[1,0.95,0.9]

img_tinted = skimage.transform.resize(img_tinted,(300,300))

skimage.io.imsave('../images/cat_inited.jpg',img_tinted)
# Out:
# Lossy conversion from float64 to uint8. Range [0.0, 255.00000000000003]. Convert image to uint8 prior to saving to suppress this warning.
# uint8 (400, 248, 3)

# %%
import numpy as np 
from scipy.spatial.distance import pdist, squareform

x = np.array([[0,1],[1,0],[2,0]])
print(x)

d = squareform(pdist(x,'euclidean'))
print(d)
# Out:
# [[0 1]
#  [1 0]
#  [2 0]]
# [[0.         1.41421356 2.23606798]
#  [1.41421356 0.         1.        ]
#  [2.23606798 1.         0.        ]]

# %%
#Matplotlib

#Plotting

import numpy as np 
import matplotlib.pyplot as plt 

x = np.arange(0,3*np.pi,0.1)
y = np.sin(x)

plt.plot(x,y)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt 

x = np.arange(0,3 * np.pi, 0.1)
y_sin = np.sin(x)
y_cos = np.cos(x)

plt.plot(x,y_sin)
plt.plot(x,y_cos)
plt.xlabel('x axis label')
plt.ylabel('y axis label')
plt.title('Sine and Cosine')
#legend 범례
plt.legend(['Sine','Cosine'])
plt.show()

# %%
#Subplots

import numpy as np 
import matplotlib.pyplot as plt 

x = np.arange(0,3*np.pi,0.1)
y_sin = np.sin(x)
y_cos = np.cos(x)

plt.subplot(2,1,1)
plt.plot(x,y_sin)
plt.title('Sine')

plt.subplot(2,1,2)
plt.plot(x,y_cos)
plt.title('Cosine')

plt.show()

# %%
import numpy as np 
import skimage.io 
import skimage.transform

img=skimage.io.imread('../images/cat.jpg')
img_tinted = img * [1,0.95,0.9]

plt.subplot(1,2,1)
plt.imshow(img)

plt.subplot(1,2,2)
plt.imshow(np.uint8(img_tinted))
plt.show()
